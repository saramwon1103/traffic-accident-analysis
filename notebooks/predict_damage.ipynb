# %%
import pandas as pd
import numpy as np

# Số dòng dữ liệu muốn tạo
n_samples = 500

# Tạo dữ liệu mô phỏng
df = pd.DataFrame({
    'traffic_control_device': np.random.choice([
        'TRAFFIC SIGNAL', 'NO CONTROLS', 'STOP SIGN/FLASHER', 'UNKNOWN', 'OTHER', 
        'PEDESTRIAN CROSSING SIGN', 'OTHER WARNING SIGN', 'YIELD', 
        'FLASHING CONTROL SIGNAL', 'LANE USE MARKING', 'OTHER REG. SIGN', 
        'DELINEATORS', 'SCHOOL ZONE', 'POLICE/FLAGMAN', 'NO PASSING', 
        'RR CROSSING SIGN', 'RAILROAD CROSSING GATE', 'BICYCLE CROSSING SIGN', 
        'OTHER RAILROAD CROSSING'], n_samples),
    'weather_condition': np.random.choice([
        'CLEAR', 'RAIN', 'SNOW', 'CLOUDY/OVERCAST', 'UNKNOWN', 'FOG/SMOKE/HAZE', 
        'BLOWING SNOW', 'FREEZING RAIN/DRIZZLE', 'OTHER', 'SLEET/HAIL', 
        'SEVERE CROSS WIND GATE', 'BLOWING SAND', 'SOIL', 'DIRT'], n_samples),
    'lighting_condition': np.random.choice([
        'DAYLIGHT', 'DARKNESS', 'LIGHTED ROAD', 'DUSK', 'UNKNOWN', 'DAWN'], n_samples),
    'first_crash_type': np.random.choice([
        'TURNING', 'REAR END', 'ANGLE', 'FIXED OBJECT', 'REAR TO FRONT', 
        'SIDESWIPE SAME DIRECTION', 'SIDESWIPE OPPOSITE DIRECTION', 'PEDALCYCLIST', 
        'PEDESTRIAN', 'HEAD ON', 'PARKED MOTOR VEHICLE', 'OTHER NONCOLLISION', 
        'OVERTURNED', 'OTHER OBJECT', 'REAR TO SIDE', 'ANIMAL', 'TRAIN', 
        'REAR TO REAR'], n_samples),
    'trafficway_type': np.random.choice([
        'NOT DIVIDED', 'FOUR WAY', 'T-INTERSECTION', 'DIVIDED - W/MEDIAN (NOT RAISED)', 
        'OTHER', 'UNKNOWN INTERSECTION TYPE', 'ONE-WAY', 'RAMP', 'TRAFFIC ROUTE', 
        'FIVE POINT, OR MORE', 'DIVIDED - W/MEDIAN BARRIER', 'UNKNOWN', 'ALLEY', 
        'CENTER TURN LANE', 'L-INTERSECTION', 'DRIVEWAY', 'Y-INTERSECTION', 
        'PARKING LOT', 'ROUN'], n_samples),
    'alignment': np.random.choice([
        'STRAIGHT AND LEVEL', 'CURVE', 'LEVEL', 'STRAIGHT ON HILLCREST', 
        'STRAIGHT ON GRADE', 'CURVE ON GRADE', 'CURVE ON HILLCREST'], n_samples),
    'roadway_surface_cond': np.random.choice([
        'UNKNOWN', 'DRY', 'WET', 'SNOW OR SLUSH', 'ICE', 'OTHER', 
        'SAND', 'MUD', 'DIRT'], n_samples),
    'road_defect': np.random.choice([
        'UNKNOWN', 'NO DEFECTS', 'OTHER', 'SHOULDER DEFECT', 'WORN SURFACE', 
        'DEBRIS ON ROADWAY', 'RUT', 'HOLES'], n_samples),
    'crash_type': np.random.choice([
        'NO INJURY / DRIVE AWAY', 'INJURY AND / OR TOW DUE TO CRASH'], n_samples),
    'intersection_related_i': np.random.choice(['Y', 'N'], n_samples),
    'damage': np.random.choice([
        '$501 - $1,500', 'OVER $1,500', '$500 OR LESS'], n_samples),
    'prim_contributory_cause': np.random.choice([
        'UNABLE TO DETERMINE', 'IMPROPER TURNING/NO SIGNAL', 'FOLLOWING TOO CLOSELY', 
        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE', 'IMPROPER BACKING', 
        'FAILING TO YIELD RIGHT-OF-WAY', 'IMPROPER OVERTAKING/PASSING', 
        'DRIVING ON WRONG SIDE/WRONG WAY', 'IMPROPER LANE USAGE', 'NOT APPLICABLE', 
        'FAILING TO REDUCE SPEED TO AVOID CRASH', 'DISREGARDING TRAFFIC SIGNALS', 
        'WEATHER', 'DISREGARDING STOP SIGN', 'EQUIPMENT - VEHICLE CONDITION', 
        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER', 
        'DISREGARDING OTHER TRAFFIC SIGNS', 'TURNING RIGHT ON RED', 
        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)', 
        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST', 
        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)', 
        'DISTRACTION - FROM OUTSIDE VEHICLE', 'EXCEEDING SAFE SPEED FOR CONDITIONS', 
        'DISREGARDING ROAD MARKINGS', 'ROAD ENGINEERING/SURFACE/MARKING DEFECTS', 
        'PHYSICAL CONDITION OF DRIVER', 'DISTRACTION - FROM INSIDE VEHICLE', 
        'EXCEEDING AUTHORIZED SPEED LIMIT', 'ROAD CONSTRUCTION/MAINTENANCE', 
        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)', 
        'ANIMAL', 'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)', 
        'BICYCLE ADVANCING LEGALLY ON RED LIGHT', 'CELL PHONE USE OTHER THAN TEXTING', 
        'RELATED TO BUS STOP', 'TEXTING', 'OBSTRUCTED CROSSWALKS', 
        'DISREGARDING YIELD SIGN', 'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT', 
        'PASSING STOPPED SCHOOL BUS'], n_samples),
    'num_units': np.random.randint(1, 12, n_samples),
    'most_severe_injury': np.random.choice([
        'NO INDICATION OF INJURY', 'NONINCAPACITATING INJURY', 
        'INCAPACITATING INJURY', 'REPORTED, NOT EVIDENT', 'FATAL'], n_samples),
    'injuries_total': np.random.randint(0, 20, n_samples),
    'injuries_fatal': np.random.randint(0, 4, n_samples),
    'injuries_incapacitating': np.random.randint(0, 8, n_samples),
    'injuries_non_incapacitating': np.random.randint(0, 22, n_samples),
    'injuries_reported_not_evident': np.random.randint(0, 16, n_samples),
    'injuries_no_indication': np.random.randint(0, 50, n_samples),
    'crash_hour': np.random.randint(0, 24, n_samples),
    'crash_day_of_week': np.random.randint(1, 8, n_samples),
    'crash_month': np.random.randint(1, 13, n_samples),
})

# Lưu ra file CSV
df.to_csv('../data/simulated_crash_data.csv', index=False)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Đọc dataset từ file CSV
df = pd.read_csv(r"..\data\simulated_crash_data.csv", encoding='utf-8')  # Thử với utf-8 hoặc ISO-8859-1

# Xóa cột "crash_date" nếu tồn tại
if "crash_date" in df.columns:
    df = df.drop(columns=["crash_date"])
    
true_labels = df['damage'].values

if "damage" in df.columns:
    df = df.drop(columns=["damage"])

# Các cột cần mã hóa
categorical_columns = [
    "traffic_control_device", "weather_condition", "lighting_condition", "first_crash_type", 
    "trafficway_type", "alignment", "roadway_surface_cond", "road_defect", "crash_type", 
    "intersection_related_i", "prim_contributory_cause", "most_severe_injury"
]

# Dictionary để lưu các label encoder
decoders = {}

# Mã hóa từng cột
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Thay đổi trực tiếp giá trị trong cột
    decoders[col] = dict(zip(le.classes_, le.transform(le.classes_)))  # Lưu mapping cho báo cáo

# Lưu dataset đã mã hóa
df.to_csv('../data/new_data_cleaned.csv', index=False)

# %%
import torch 
import pandas as pd 
import networkx as nx 
from itertools import combinations
from torch_geometric.data import Data 
from model import GAT

# %%
# Đọc dataset
file_path = r'..\data\new_data_cleaned.csv'
df = pd.read_csv(file_path)

# %%
import networkx as nx
from itertools import combinations

G = nx.Graph()
for index, row in df.iterrows():
    G.add_node(index, **row.to_dict())

def is_similar(accident1, accident2):
    return (
        abs(accident1['crash_hour'] - accident2['crash_hour']) <= 1 or
        accident1['crash_month'] == accident2['crash_month'] or
        accident1['crash_day_of_week'] == accident2['crash_day_of_week'] or
        accident1['trafficway_type'] == accident2['trafficway_type'] or
        accident1['first_crash_type'] == accident2['first_crash_type'] or
        accident1['injuries_no_indication'] == accident2['injuries_no_indication']
    )

for u, v in combinations(G.nodes(data=True), 2):
    if is_similar(u[1], v[1]):
        G.add_edge(u[0], v[0])

print(f"Đã tạo đồ thị với {G.number_of_nodes()} nút và {G.number_of_edges()} cạnh.")
# Out:
# Đã tạo đồ thị với 500 nút và 49525 cạnh.

# %%
import torch
from torch_geometric.data import Data

def networkx_to_pyg_inference(G):
    feature_attrs = list(next(iter(G.nodes(data=True)))[1].keys())

    features = [
        [float(data[attr]) for attr in feature_attrs]
        for _, data in G.nodes(data=True)
    ]

    x = torch.tensor(features, dtype=torch.float)

    node_mapping = {node: i for i, node in enumerate(G.nodes())}
    edge_index = torch.tensor(
        [[node_mapping[u], node_mapping[v]] for u, v in G.edges()],
        dtype=torch.long
    ).t().contiguous()

    return Data(x=x, edge_index=edge_index)

data_new = networkx_to_pyg_inference(G)

# %%
import torch
from torch.serialization import safe_globals

# Dùng context manager để an toàn khi unpickle class GAT
with safe_globals([GAT]):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = torch.load('gat_model.pth', map_location=device, weights_only=False)
    model.eval()

# %%
with torch.no_grad():
    out = model(data_new.x.to(device), data_new.edge_index.to(device))
    pred = out.argmax(dim=1)

df['predicted_damage'] = pred.cpu().numpy()

# %%
# Thêm giá trị predicted_damage vào đồ thị
for i, pred in enumerate(pred.cpu().numpy()):
    G.nodes[i]['predicted_damage'] = pred

# Kiểm tra lại giá trị đã được gán đúng chưa
for i in range(len(df)):
    print(f"Node {i} has predicted_damage = {G.nodes[i].get('predicted_damage')}")
# Out:
# Node 0 has predicted_damage = 2
# Node 1 has predicted_damage = 2
# Node 2 has predicted_damage = 2
# Node 3 has predicted_damage = 2
# Node 4 has predicted_damage = 2
# Node 5 has predicted_damage = 2
# Node 6 has predicted_damage = 2
# Node 7 has predicted_damage = 2
# Node 8 has predicted_damage = 2
# Node 9 has predicted_damage = 2
# Node 10 has predicted_damage = 2
# Node 11 has predicted_damage = 2
# Node 12 has predicted_damage = 2
# Node 13 has predicted_damage = 2
# Node 14 has predicted_damage = 2
# Node 15 has predicted_damage = 2
# Node 16 has predicted_damage = 2
# Node 17 has predicted_damage = 2
# Node 18 has predicted_damage = 2
# Node 19 has predicted_damage = 2
# Node 20 has predicted_damage = 2
# Node 21 has predicted_damage = 2
# Node 22 has predicted_damage = 2
# Node 23 has predicted_damage = 2
# Node 24 has predicted_damage = 2
# Node 25 has predicted_damage = 2
# Node 26 has predicted_damage = 2
# Node 27 has predicted_damage = 2
# Node 28 has predicted_damage = 2
# Node 29 has predicted_damage = 2
# Node 30 has predicted_damage = 2
# Node 31 has predicted_damage = 2
# Node 32 has predicted_damage = 2
# Node 33 has predicted_damage = 2
# Node 34 has predicted_damage = 2
# Node 35 has predicted_damage = 2
# Node 36 has predicted_damage = 2
# Node 37 has predicted_damage = 2
# Node 38 has predicted_damage = 2
# Node 39 has predicted_damage = 2
# Node 40 has predicted_damage = 2
# Node 41 has predicted_damage = 2
# Node 42 has predicted_damage = 2
# Node 43 has predicted_damage = 2
# Node 44 has predicted_damage = 2
# Node 45 has predicted_damage = 2
# Node 46 has predicted_damage = 2
# Node 47 has predicted_damage = 2
# Node 48 has predicted_damage = 2
# Node 49 has predicted_damage = 2
# Node 50 has predicted_damage = 2
# Node 51 has predicted_damage = 2
# Node 52 has predicted_damage = 2
# Node 53 has predicted_damage = 2
# Node 54 has predicted_damage = 2
# Node 55 has predicted_damage = 2
# Node 56 has predicted_damage = 2
# Node 57 has predicted_damage = 2
# Node 58 has predicted_damage = 2
# Node 59 has predicted_damage = 2
# Node 60 has predicted_damage = 2
# Node 61 has predicted_damage = 2
# Node 62 has predicted_damage = 2
# Node 63 has predicted_damage = 2
# Node 64 has predicted_damage = 2
# Node 65 has predicted_damage = 2
# Node 66 has predicted_damage = 2
# Node 67 has predicted_damage = 2
# Node 68 has predicted_damage = 2
# Node 69 has predicted_damage = 2
# Node 70 has predicted_damage = 2
# Node 71 has predicted_damage = 2
# Node 72 has predicted_damage = 2
# Node 73 has predicted_damage = 2
# Node 74 has predicted_damage = 2
# Node 75 has predicted_damage = 2
# Node 76 has predicted_damage = 2
# Node 77 has predicted_damage = 2
# Node 78 has predicted_damage = 2
# Node 79 has predicted_damage = 2
# Node 80 has predicted_damage = 2
# Node 81 has predicted_damage = 2
# Node 82 has predicted_damage = 2
# Node 83 has predicted_damage = 2
# Node 84 has predicted_damage = 2
# Node 85 has predicted_damage = 2
# Node 86 has predicted_damage = 2
# Node 87 has predicted_damage = 2
# Node 88 has predicted_damage = 2
# Node 89 has predicted_damage = 2
# Node 90 has predicted_damage = 2
# Node 91 has predicted_damage = 2
# Node 92 has predicted_damage = 2
# Node 93 has predicted_damage = 2
# Node 94 has predicted_damage = 2
# Node 95 has predicted_damage = 2
# Node 96 has predicted_damage = 2
# Node 97 has predicted_damage = 2
# Node 98 has predicted_damage = 2
# Node 99 has predicted_damage = 2
# Node 100 has predicted_damage = 2
# Node 101 has predicted_damage = 2
# Node 102 has predicted_damage = 2
# Node 103 has predicted_damage = 2
# Node 104 has predicted_damage = 2
# Node 105 has predicted_damage = 2
# Node 106 has predicted_damage = 2
# Node 107 has predicted_damage = 2
# Node 108 has predicted_damage = 2
# Node 109 has predicted_damage = 2
# Node 110 has predicted_damage = 2
# Node 111 has predicted_damage = 2
# Node 112 has predicted_damage = 2
# Node 113 has predicted_damage = 2
# Node 114 has predicted_damage = 2
# Node 115 has predicted_damage = 2
# Node 116 has predicted_damage = 2
# Node 117 has predicted_damage = 2
# Node 118 has predicted_damage = 2
# Node 119 has predicted_damage = 2
# Node 120 has predicted_damage = 2
# Node 121 has predicted_damage = 2
# Node 122 has predicted_damage = 2
# Node 123 has predicted_damage = 2
# Node 124 has predicted_damage = 2
# Node 125 has predicted_damage = 2
# Node 126 has predicted_damage = 2
# Node 127 has predicted_damage = 2
# Node 128 has predicted_damage = 2
# Node 129 has predicted_damage = 2
# Node 130 has predicted_damage = 2
# Node 131 has predicted_damage = 2
# Node 132 has predicted_damage = 2
# Node 133 has predicted_damage = 2
# Node 134 has predicted_damage = 2
# Node 135 has predicted_damage = 2
# Node 136 has predicted_damage = 2
# Node 137 has predicted_damage = 2
# Node 138 has predicted_damage = 2
# Node 139 has predicted_damage = 2
# Node 140 has predicted_damage = 2
# Node 141 has predicted_damage = 2
# Node 142 has predicted_damage = 2
# Node 143 has predicted_damage = 2
# Node 144 has predicted_damage = 2
# Node 145 has predicted_damage = 2
# Node 146 has predicted_damage = 2
# Node 147 has predicted_damage = 2
# Node 148 has predicted_damage = 2
# Node 149 has predicted_damage = 2
# Node 150 has predicted_damage = 2
# Node 151 has predicted_damage = 2
# Node 152 has predicted_damage = 2
# Node 153 has predicted_damage = 2
# Node 154 has predicted_damage = 2
# Node 155 has predicted_damage = 2
# Node 156 has predicted_damage = 2
# Node 157 has predicted_damage = 2
# Node 158 has predicted_damage = 2
# Node 159 has predicted_damage = 2
# Node 160 has predicted_damage = 2
# Node 161 has predicted_damage = 2
# Node 162 has predicted_damage = 2
# Node 163 has predicted_damage = 2
# Node 164 has predicted_damage = 2
# Node 165 has predicted_damage = 2
# Node 166 has predicted_damage = 2
# Node 167 has predicted_damage = 2
# Node 168 has predicted_damage = 2
# Node 169 has predicted_damage = 2
# Node 170 has predicted_damage = 2
# Node 171 has predicted_damage = 2
# Node 172 has predicted_damage = 2
# Node 173 has predicted_damage = 2
# Node 174 has predicted_damage = 2
# Node 175 has predicted_damage = 2
# Node 176 has predicted_damage = 2
# Node 177 has predicted_damage = 2
# Node 178 has predicted_damage = 2
# Node 179 has predicted_damage = 2
# Node 180 has predicted_damage = 2
# Node 181 has predicted_damage = 2
# Node 182 has predicted_damage = 2
# Node 183 has predicted_damage = 2
# Node 184 has predicted_damage = 2
# Node 185 has predicted_damage = 2
# Node 186 has predicted_damage = 2
# Node 187 has predicted_damage = 2
# Node 188 has predicted_damage = 2
# Node 189 has predicted_damage = 2
# Node 190 has predicted_damage = 2
# Node 191 has predicted_damage = 2
# Node 192 has predicted_damage = 2
# Node 193 has predicted_damage = 2
# Node 194 has predicted_damage = 2
# Node 195 has predicted_damage = 2
# Node 196 has predicted_damage = 2
# Node 197 has predicted_damage = 2
# Node 198 has predicted_damage = 2
# Node 199 has predicted_damage = 2
# Node 200 has predicted_damage = 2
# Node 201 has predicted_damage = 2
# Node 202 has predicted_damage = 2
# Node 203 has predicted_damage = 2
# Node 204 has predicted_damage = 2
# Node 205 has predicted_damage = 2
# Node 206 has predicted_damage = 2
# Node 207 has predicted_damage = 2
# Node 208 has predicted_damage = 2
# Node 209 has predicted_damage = 2
# Node 210 has predicted_damage = 2
# Node 211 has predicted_damage = 2
# Node 212 has predicted_damage = 2
# Node 213 has predicted_damage = 2
# Node 214 has predicted_damage = 2
# Node 215 has predicted_damage = 2
# Node 216 has predicted_damage = 2
# Node 217 has predicted_damage = 2
# Node 218 has predicted_damage = 2
# Node 219 has predicted_damage = 2
# Node 220 has predicted_damage = 2
# Node 221 has predicted_damage = 2
# Node 222 has predicted_damage = 2
# Node 223 has predicted_damage = 2
# Node 224 has predicted_damage = 2
# Node 225 has predicted_damage = 2
# Node 226 has predicted_damage = 2
# Node 227 has predicted_damage = 2
# Node 228 has predicted_damage = 2
# Node 229 has predicted_damage = 2
# Node 230 has predicted_damage = 2
# Node 231 has predicted_damage = 2
# Node 232 has predicted_damage = 2
# Node 233 has predicted_damage = 2
# Node 234 has predicted_damage = 2
# Node 235 has predicted_damage = 2
# Node 236 has predicted_damage = 2
# Node 237 has predicted_damage = 2
# Node 238 has predicted_damage = 2
# Node 239 has predicted_damage = 2
# Node 240 has predicted_damage = 2
# Node 241 has predicted_damage = 2
# Node 242 has predicted_damage = 2
# Node 243 has predicted_damage = 2
# Node 244 has predicted_damage = 2
# Node 245 has predicted_damage = 2
# Node 246 has predicted_damage = 2
# Node 247 has predicted_damage = 2
# Node 248 has predicted_damage = 2
# Node 249 has predicted_damage = 2
# Node 250 has predicted_damage = 2
# Node 251 has predicted_damage = 2
# Node 252 has predicted_damage = 2
# Node 253 has predicted_damage = 2
# Node 254 has predicted_damage = 2
# Node 255 has predicted_damage = 2
# Node 256 has predicted_damage = 2
# Node 257 has predicted_damage = 2
# Node 258 has predicted_damage = 2
# Node 259 has predicted_damage = 2
# Node 260 has predicted_damage = 2
# Node 261 has predicted_damage = 2
# Node 262 has predicted_damage = 2
# Node 263 has predicted_damage = 2
# Node 264 has predicted_damage = 2
# Node 265 has predicted_damage = 2
# Node 266 has predicted_damage = 2
# Node 267 has predicted_damage = 2
# Node 268 has predicted_damage = 2
# Node 269 has predicted_damage = 2
# Node 270 has predicted_damage = 2
# Node 271 has predicted_damage = 2
# Node 272 has predicted_damage = 2
# Node 273 has predicted_damage = 2
# Node 274 has predicted_damage = 2
# Node 275 has predicted_damage = 2
# Node 276 has predicted_damage = 2
# Node 277 has predicted_damage = 2
# Node 278 has predicted_damage = 2
# Node 279 has predicted_damage = 2
# Node 280 has predicted_damage = 2
# Node 281 has predicted_damage = 2
# Node 282 has predicted_damage = 2
# Node 283 has predicted_damage = 2
# Node 284 has predicted_damage = 2
# Node 285 has predicted_damage = 2
# Node 286 has predicted_damage = 2
# Node 287 has predicted_damage = 2
# Node 288 has predicted_damage = 2
# Node 289 has predicted_damage = 2
# Node 290 has predicted_damage = 2
# Node 291 has predicted_damage = 2
# Node 292 has predicted_damage = 2
# Node 293 has predicted_damage = 2
# Node 294 has predicted_damage = 2
# Node 295 has predicted_damage = 2
# Node 296 has predicted_damage = 2
# Node 297 has predicted_damage = 2
# Node 298 has predicted_damage = 2
# Node 299 has predicted_damage = 2
# Node 300 has predicted_damage = 2
# Node 301 has predicted_damage = 2
# Node 302 has predicted_damage = 2
# Node 303 has predicted_damage = 2
# Node 304 has predicted_damage = 2
# Node 305 has predicted_damage = 2
# Node 306 has predicted_damage = 2
# Node 307 has predicted_damage = 2
# Node 308 has predicted_damage = 2
# Node 309 has predicted_damage = 2
# Node 310 has predicted_damage = 2
# Node 311 has predicted_damage = 2
# Node 312 has predicted_damage = 2
# Node 313 has predicted_damage = 2
# Node 314 has predicted_damage = 2
# Node 315 has predicted_damage = 2
# Node 316 has predicted_damage = 2
# Node 317 has predicted_damage = 2
# Node 318 has predicted_damage = 2
# Node 319 has predicted_damage = 2
# Node 320 has predicted_damage = 2
# Node 321 has predicted_damage = 2
# Node 322 has predicted_damage = 2
# Node 323 has predicted_damage = 2
# Node 324 has predicted_damage = 2
# Node 325 has predicted_damage = 2
# Node 326 has predicted_damage = 2
# Node 327 has predicted_damage = 2
# Node 328 has predicted_damage = 2
# Node 329 has predicted_damage = 2
# Node 330 has predicted_damage = 2
# Node 331 has predicted_damage = 2
# Node 332 has predicted_damage = 2
# Node 333 has predicted_damage = 2
# Node 334 has predicted_damage = 2
# Node 335 has predicted_damage = 2
# Node 336 has predicted_damage = 2
# Node 337 has predicted_damage = 2
# Node 338 has predicted_damage = 2
# Node 339 has predicted_damage = 2
# Node 340 has predicted_damage = 2
# Node 341 has predicted_damage = 2
# Node 342 has predicted_damage = 2
# Node 343 has predicted_damage = 2
# Node 344 has predicted_damage = 2
# Node 345 has predicted_damage = 2
# Node 346 has predicted_damage = 2
# Node 347 has predicted_damage = 2
# Node 348 has predicted_damage = 2
# Node 349 has predicted_damage = 2
# Node 350 has predicted_damage = 2
# Node 351 has predicted_damage = 2
# Node 352 has predicted_damage = 2
# Node 353 has predicted_damage = 2
# Node 354 has predicted_damage = 2
# Node 355 has predicted_damage = 2
# Node 356 has predicted_damage = 2
# Node 357 has predicted_damage = 2
# Node 358 has predicted_damage = 2
# Node 359 has predicted_damage = 2
# Node 360 has predicted_damage = 2
# Node 361 has predicted_damage = 2
# Node 362 has predicted_damage = 2
# Node 363 has predicted_damage = 2
# Node 364 has predicted_damage = 2
# Node 365 has predicted_damage = 2
# Node 366 has predicted_damage = 2
# Node 367 has predicted_damage = 2
# Node 368 has predicted_damage = 2
# Node 369 has predicted_damage = 2
# Node 370 has predicted_damage = 2
# Node 371 has predicted_damage = 2
# Node 372 has predicted_damage = 2
# Node 373 has predicted_damage = 2
# Node 374 has predicted_damage = 2
# Node 375 has predicted_damage = 2
# Node 376 has predicted_damage = 2
# Node 377 has predicted_damage = 2
# Node 378 has predicted_damage = 2
# Node 379 has predicted_damage = 2
# Node 380 has predicted_damage = 2
# Node 381 has predicted_damage = 2
# Node 382 has predicted_damage = 2
# Node 383 has predicted_damage = 2
# Node 384 has predicted_damage = 2
# Node 385 has predicted_damage = 2
# Node 386 has predicted_damage = 2
# Node 387 has predicted_damage = 2
# Node 388 has predicted_damage = 2
# Node 389 has predicted_damage = 2
# Node 390 has predicted_damage = 2
# Node 391 has predicted_damage = 2
# Node 392 has predicted_damage = 2
# Node 393 has predicted_damage = 2
# Node 394 has predicted_damage = 2
# Node 395 has predicted_damage = 2
# Node 396 has predicted_damage = 2
# Node 397 has predicted_damage = 2
# Node 398 has predicted_damage = 2
# Node 399 has predicted_damage = 2
# Node 400 has predicted_damage = 2
# Node 401 has predicted_damage = 2
# Node 402 has predicted_damage = 2
# Node 403 has predicted_damage = 2
# Node 404 has predicted_damage = 2
# Node 405 has predicted_damage = 2
# Node 406 has predicted_damage = 2
# Node 407 has predicted_damage = 2
# Node 408 has predicted_damage = 2
# Node 409 has predicted_damage = 2
# Node 410 has predicted_damage = 2
# Node 411 has predicted_damage = 2
# Node 412 has predicted_damage = 2
# Node 413 has predicted_damage = 2
# Node 414 has predicted_damage = 2
# Node 415 has predicted_damage = 2
# Node 416 has predicted_damage = 2
# Node 417 has predicted_damage = 2
# Node 418 has predicted_damage = 2
# Node 419 has predicted_damage = 2
# Node 420 has predicted_damage = 2
# Node 421 has predicted_damage = 2
# Node 422 has predicted_damage = 2
# Node 423 has predicted_damage = 2
# Node 424 has predicted_damage = 2
# Node 425 has predicted_damage = 2
# Node 426 has predicted_damage = 2
# Node 427 has predicted_damage = 2
# Node 428 has predicted_damage = 2
# Node 429 has predicted_damage = 2
# Node 430 has predicted_damage = 2
# Node 431 has predicted_damage = 2
# Node 432 has predicted_damage = 2
# Node 433 has predicted_damage = 2
# Node 434 has predicted_damage = 2
# Node 435 has predicted_damage = 2
# Node 436 has predicted_damage = 2
# Node 437 has predicted_damage = 2
# Node 438 has predicted_damage = 2
# Node 439 has predicted_damage = 2
# Node 440 has predicted_damage = 2
# Node 441 has predicted_damage = 2
# Node 442 has predicted_damage = 2
# Node 443 has predicted_damage = 2
# Node 444 has predicted_damage = 2
# Node 445 has predicted_damage = 2
# Node 446 has predicted_damage = 2
# Node 447 has predicted_damage = 2
# Node 448 has predicted_damage = 2
# Node 449 has predicted_damage = 2
# Node 450 has predicted_damage = 2
# Node 451 has predicted_damage = 2
# Node 452 has predicted_damage = 2
# Node 453 has predicted_damage = 2
# Node 454 has predicted_damage = 2
# Node 455 has predicted_damage = 2
# Node 456 has predicted_damage = 2
# Node 457 has predicted_damage = 2
# Node 458 has predicted_damage = 2
# Node 459 has predicted_damage = 2
# Node 460 has predicted_damage = 2
# Node 461 has predicted_damage = 2
# Node 462 has predicted_damage = 2
# Node 463 has predicted_damage = 2
# Node 464 has predicted_damage = 2
# Node 465 has predicted_damage = 2
# Node 466 has predicted_damage = 2
# Node 467 has predicted_damage = 2
# Node 468 has predicted_damage = 2
# Node 469 has predicted_damage = 2
# Node 470 has predicted_damage = 2
# Node 471 has predicted_damage = 2
# Node 472 has predicted_damage = 2
# Node 473 has predicted_damage = 2
# Node 474 has predicted_damage = 2
# Node 475 has predicted_damage = 2
# Node 476 has predicted_damage = 2
# Node 477 has predicted_damage = 2
# Node 478 has predicted_damage = 2
# Node 479 has predicted_damage = 2
# Node 480 has predicted_damage = 2
# Node 481 has predicted_damage = 2
# Node 482 has predicted_damage = 2
# Node 483 has predicted_damage = 2
# Node 484 has predicted_damage = 2
# Node 485 has predicted_damage = 2
# Node 486 has predicted_damage = 2
# Node 487 has predicted_damage = 2
# Node 488 has predicted_damage = 2
# Node 489 has predicted_damage = 2
# Node 490 has predicted_damage = 2
# Node 491 has predicted_damage = 2
# Node 492 has predicted_damage = 2
# Node 493 has predicted_damage = 2
# Node 494 has predicted_damage = 2
# Node 495 has predicted_damage = 2
# Node 496 has predicted_damage = 2
# Node 497 has predicted_damage = 2
# Node 498 has predicted_damage = 2
# Node 499 has predicted_damage = 2

# %%
# Mapping số về chuỗi như trong cột damage gốc
damage_mapping = {
    0: "$500 OR LESS",
    1: "$501 - $1,500",
    2: "OVER $1,500"
}

# Tạo cột mới với nhãn dạng chuỗi
df['predicted_damage_label'] = df['predicted_damage'].map(damage_mapping)

print(df[['predicted_damage', 'predicted_damage_label']])
# Out:
#      predicted_damage predicted_damage_label
# 0                   2            OVER $1,500
# 1                   2            OVER $1,500
# 2                   2            OVER $1,500
# 3                   2            OVER $1,500
# 4                   2            OVER $1,500
# ..                ...                    ...
# 495                 2            OVER $1,500
# 496                 2            OVER $1,500
# 497                 2            OVER $1,500
# 498                 2            OVER $1,500
# 499                 2            OVER $1,500
#
# [500 rows x 2 columns]

# %%
from collections import Counter, defaultdict

def analyze_high_damage_nodes(G, label_attr='predicted_damage', high_level=1, top_k=3):
    # Bước 1: Lọc các node có predicted_damage bằng high_level
    high_damage_nodes = [n for n, data in G.nodes(data=True) if data.get(label_attr) == high_level]

    # Kiểm tra nếu không có node nào
    if not high_damage_nodes:
        print(f"No nodes found with {label_attr} = {high_level}")
        return

    # Bước 2: Thống kê các feature xuất hiện trong nhóm này
    feature_counters = defaultdict(Counter)

    for n in high_damage_nodes:
        node_data = G.nodes[n]
        for attr, value in node_data.items():
            if attr != label_attr:
                feature_counters[attr][value] += 1

    # Bước 3: In ra top K giá trị phổ biến nhất cho từng feature
    print(f"\nTop nguyên nhân thường thấy khi `{label_attr} = {high_level}`:\n")
    for attr, counter in feature_counters.items():
        print(f"- {attr}:")
        for val, freq in counter.most_common(top_k):
            print(f"   • {val}: {freq} lần")
        print()

# %%
analyze_high_damage_nodes(G, label_attr='predicted_damage', high_level=0)
# Out:
# No nodes found with predicted_damage = 0

# %%
analyze_high_damage_nodes(G, label_attr='predicted_damage', high_level=1)
# Out:
# No nodes found with predicted_damage = 1

# %%
import matplotlib.pyplot as plt

# Gán nhãn dự đoán vào thuộc tính của node trong đồ thị
for idx, label in enumerate(df['predicted_damage']):
    G.nodes[idx]['predicted_damage'] = label

# Ánh xạ damage thành màu
color_map = {
    0: 'green',     # "$500 OR LESS"
    1: 'orange',    # "$501 - $1,500"
    2: 'red'        # "OVER $1,500"
}

# Tạo danh sách màu cho mỗi node
node_colors = [color_map[G.nodes[n]['predicted_damage']] for n in G.nodes]

# Tùy chọn: giảm số lượng node để dễ hiển thị (ví dụ chỉ 50 nodes)
sub_nodes = list(G.nodes)[:50]
subgraph = G.subgraph(sub_nodes)

# Vẽ đồ thị con với màu
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(subgraph, seed=42)  # layout đẹp hơn
nx.draw(
    subgraph,
    pos,
    with_labels=True,
    node_color=[color_map[G.nodes[n]['predicted_damage']] for n in subgraph.nodes],
    node_size=500,
    font_size=8,
    edge_color='gray',
    alpha=0.8
)
# Tạo chú thích
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='green', label='$500 OR LESS'),
    Patch(facecolor='orange', label='$501 - $1,500'),
    Patch(facecolor='red', label='OVER $1,500'),
]
plt.legend(handles=legend_elements, title="Predicted Damage", loc='best')
plt.title("Trực quan hóa dự đoán thiệt hại tai nạn")
plt.axis('off')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.metrics import roc_auc_score, RocCurveDisplay, confusion_matrix, ConfusionMatrixDisplay, classification_report
import seaborn as sns

# Giả sử chúng ta có:
# - true_labels: nhãn thực tế (giá trị gốc từ cột 'damage')
# - df['predicted_damage']: dự đoán từ mô hình (đã được ánh xạ thành 0,1,2)

# Chuyển true_labels từ chuỗi sang số
damage_mapping = {
    '$500 OR LESS': 0,
    '$501 - $1,500': 1,
    'OVER $1,500': 2
}

# Chuyển đổi nhãn thực tế và dự đoán
true_labels_encoded = np.array([damage_mapping[label] for label in true_labels])
y_pred = df['predicted_damage'].values  # Đã là 0,1,2

# Binarize các nhãn cho ROC-AUC (cần cho multi-class)
y_true_bin = label_binarize(true_labels_encoded, classes=[0, 1, 2])
y_pred_bin = label_binarize(y_pred, classes=[0, 1, 2])

# Tính ROC-AUC cho từng lớp và trung bình
roc_auc_scores = {}
for i in range(3):
    roc_auc_scores[f"Lớp {i} ({list(damage_mapping.keys())[i]})"] = roc_auc_score(
        y_true_bin[:, i], 
        y_pred_bin[:, i]
    )
roc_auc_scores["Trung bình"] = roc_auc_score(
    y_true_bin, 
    y_pred_bin, 
    multi_class='ovr', 
    average='macro'
)

# In kết quả ROC-AUC
print("\nKết quả đánh giá ROC-AUC:")
for k, v in roc_auc_scores.items():
    print(f"{k}: {v:.4f}")

# Trực quan hóa ROC curves
fig, ax = plt.subplots(figsize=(10, 8))
for i in range(3):
    RocCurveDisplay.from_predictions(
        y_true_bin[:, i],
        y_pred_bin[:, i],
        name=f"Lớp {i} ({list(damage_mapping.keys())[i]})",
        ax=ax
    )
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.title('Đường cong ROC cho từng lớp')
plt.xlabel('Tỉ lệ dương tính giả (FPR)')
plt.ylabel('Tỉ lệ dương tính thật (TPR)')
plt.legend()
plt.show()

# Tính và hiển thị Confusion Matrix
cm = confusion_matrix(true_labels_encoded, y_pred)
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=list(damage_mapping.keys())
)

fig, ax = plt.subplots(figsize=(10, 8))
disp.plot(ax=ax, cmap='Blues', values_format='d')
plt.title('Confusion Matrix của mô hình dự đoán mức độ thiệt hại')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Phân tích chi tiết Confusion Matrix
print("\nPhân tích Confusion Matrix:")
for i in range(3):
    total = sum(cm[i])
    correct = cm[i,i]
    accuracy = correct / total if total > 0 else 0
    print(f"- Độ chính xác cho {list(damage_mapping.keys())[i]}: {accuracy:.2%} ({correct}/{total})")

# Tính các chỉ số precision, recall, F1
print("\nBáo cáo phân loại chi tiết:")
print(classification_report(
    true_labels_encoded, 
    y_pred, 
    target_names=list(damage_mapping.keys())
))
# Out:
# Kết quả đánh giá ROC-AUC:
# Lớp 0 ($500 OR LESS): 0.5000
# Lớp 1 ($501 - $1,500): 0.5000
# Lớp 2 (OVER $1,500): 0.5000
# Trung bình: 0.5000
# Phân tích Confusion Matrix:
# - Độ chính xác cho $500 OR LESS: 0.00% (0/163)
# - Độ chính xác cho $501 - $1,500: 0.00% (0/163)
# - Độ chính xác cho OVER $1,500: 100.00% (174/174)
#
# Báo cáo phân loại chi tiết:
#                precision    recall  f1-score   support
#
#  $500 OR LESS       0.00      0.00      0.00       163
# $501 - $1,500       0.00      0.00      0.00       163
#   OVER $1,500       0.35      1.00      0.52       174
#
#      accuracy                           0.35       500
#     macro avg       0.12      0.33      0.17       500
#  weighted avg       0.12      0.35      0.18       500
# c:\Users\QUYEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\QUYEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\QUYEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import accuracy_score, classification_report
from tabulate import tabulate
import pandas as pd

# Tính độ chính xác tổng thể
overall_accuracy = accuracy_score(true_labels_encoded, y_pred)

print("\n==============================================")
print(f"ĐỘ CHÍNH XÁC TỔNG THỂ CỦA MÔ HÌNH: {overall_accuracy:.2%}")
print("==============================================\n")

# Lấy báo cáo phân loại và chuyển sang dictionary
report = classification_report(
    true_labels_encoded, 
    y_pred, 
    target_names=list(damage_mapping.keys()),
    output_dict=True
)

# Hiển thị bảng tóm tắt các chỉ số đánh giá
metrics_table = []
for i, class_name in enumerate(damage_mapping.keys()):
    metrics_table.append([
        class_name,
        f"{report[class_name]['precision']:.2%}",
        f"{report[class_name]['recall']:.2%}",
        f"{report[class_name]['f1-score']:.2%}",
        report[class_name]['support']
    ])

# Thêm dòng tổng hợp
metrics_table.append([
    "MACRO AVG",
    f"{report['macro avg']['precision']:.2%}",
    f"{report['macro avg']['recall']:.2%}",
    f"{report['macro avg']['f1-score']:.2%}",
    report['macro avg']['support']
])

metrics_table.append([
    "WEIGHTED AVG",
    f"{report['weighted avg']['precision']:.2%}",
    f"{report['weighted avg']['recall']:.2%}",
    f"{report['weighted avg']['f1-score']:.2%}",
    report['weighted avg']['support']
])

print(tabulate(metrics_table, 
               headers=["Lớp", "Precision", "Recall", "F1-Score", "Số lượng mẫu"],
               tablefmt="grid",
               stralign="center",
               numalign="center"))

print("\nGhi chú:")
print("- Precision: Tỉ lệ dự đoán đúng trong tất cả các dự đoán thuộc lớp đó")
print("- Recall: Tỉ lệ mẫu thuộc lớp đó được dự đoán đúng")
print("- F1-Score: Trung bình điều hòa của Precision và Recall")
print("- Macro Avg: Trung bình đơn giản của các chỉ số")
print("- Weighted Avg: Trung bình có trọng số theo số lượng mẫu")

# Phân tích thêm về các trường hợp phân loại sai
error_analysis = pd.DataFrame({
    'Thực tế': [list(damage_mapping.keys())[x] for x in true_labels_encoded],
    'Dự đoán': [list(damage_mapping.keys())[x] for x in y_pred],
    'Đúng/Sai': true_labels_encoded == y_pred
})

error_cases = error_analysis[error_analysis['Đúng/Sai'] == False]
print("\n\nPHÂN TÍCH LỖI:")
print(f"Tổng số mẫu bị phân loại sai: {len(error_cases)}/{len(df)} ({len(error_cases)/len(df):.2%})")

# Ma trận nhầm lẫn giữa các lớp
confusion_pairs = error_cases.groupby(['Thực tế', 'Dự đoán']).size().unstack().fillna(0)
print("\nCHI TIẾT NHẦM LẪN GIỮA CÁC LỚP:")
print(confusion_pairs.to_string())

# Phân phối lớp
class_distribution = pd.Series([list(damage_mapping.keys())[x] for x in true_labels_encoded]).value_counts(normalize=True)
print("\nPHÂN PHỐI LỚP TRONG DỮ LIỆU:")
print(class_distribution.to_string())
# Out:
# ==============================================
# ĐỘ CHÍNH XÁC TỔNG THỂ CỦA MÔ HÌNH: 34.80%
# ==============================================
#
# +---------------+-------------+----------+------------+----------------+
# |      Lớp      |  Precision  |  Recall  |  F1-Score  |  Số lượng mẫu  |
# +===============+=============+==========+============+================+
# | $500 OR LESS  |    0.00%    |  0.00%   |   0.00%    |      163       |
# +---------------+-------------+----------+------------+----------------+
# | $501 - $1,500 |    0.00%    |  0.00%   |   0.00%    |      163       |
# +---------------+-------------+----------+------------+----------------+
# |  OVER $1,500  |   34.80%    | 100.00%  |   51.63%   |      174       |
# +---------------+-------------+----------+------------+----------------+
# |   MACRO AVG   |   11.60%    |  33.33%  |   17.21%   |      500       |
# +---------------+-------------+----------+------------+----------------+
# | WEIGHTED AVG  |   12.11%    |  34.80%  |   17.97%   |      500       |
# +---------------+-------------+----------+------------+----------------+
#
# Ghi chú:
# - Precision: Tỉ lệ dự đoán đúng trong tất cả các dự đoán thuộc lớp đó
# - Recall: Tỉ lệ mẫu thuộc lớp đó được dự đoán đúng
# - F1-Score: Trung bình điều hòa của Precision và Recall
# - Macro Avg: Trung bình đơn giản của các chỉ số
# - Weighted Avg: Trung bình có trọng số theo số lượng mẫu
#
#
# PHÂN TÍCH LỖI:
# Tổng số mẫu bị phân loại sai: 326/500 (65.20%)
#
# CHI TIẾT NHẦM LẪN GIỮA CÁC LỚP:
# Dự đoán        OVER $1,500
# Thực tế
# $500 OR LESS           163
# $501 - $1,500          163
#
# PHÂN PHỐI LỚP TRONG DỮ LIỆU:
# OVER $1,500      0.348
# $501 - $1,500    0.326
# $500 OR LESS     0.326
# c:\Users\QUYEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\QUYEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\QUYEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
