# %%
import pandas as pd
import numpy as np

# Số dòng dữ liệu muốn tạo
n_samples = 500

# Tạo dữ liệu mô phỏng
df = pd.DataFrame({
    'traffic_control_device': np.random.choice([
        'TRAFFIC SIGNAL', 'NO CONTROLS', 'STOP SIGN/FLASHER', 'UNKNOWN', 'OTHER', 
        'PEDESTRIAN CROSSING SIGN', 'OTHER WARNING SIGN', 'YIELD', 
        'FLASHING CONTROL SIGNAL', 'LANE USE MARKING', 'OTHER REG. SIGN', 
        'DELINEATORS', 'SCHOOL ZONE', 'POLICE/FLAGMAN', 'NO PASSING', 
        'RR CROSSING SIGN', 'RAILROAD CROSSING GATE', 'BICYCLE CROSSING SIGN', 
        'OTHER RAILROAD CROSSING'], n_samples),
    'weather_condition': np.random.choice([
        'CLEAR', 'RAIN', 'SNOW', 'CLOUDY/OVERCAST', 'UNKNOWN', 'FOG/SMOKE/HAZE', 
        'BLOWING SNOW', 'FREEZING RAIN/DRIZZLE', 'OTHER', 'SLEET/HAIL', 
        'SEVERE CROSS WIND GATE', 'BLOWING SAND', 'SOIL', 'DIRT'], n_samples),
    'lighting_condition': np.random.choice([
        'DAYLIGHT', 'DARKNESS', 'LIGHTED ROAD', 'DUSK', 'UNKNOWN', 'DAWN'], n_samples),
    'first_crash_type': np.random.choice([
        'TURNING', 'REAR END', 'ANGLE', 'FIXED OBJECT', 'REAR TO FRONT', 
        'SIDESWIPE SAME DIRECTION', 'SIDESWIPE OPPOSITE DIRECTION', 'PEDALCYCLIST', 
        'PEDESTRIAN', 'HEAD ON', 'PARKED MOTOR VEHICLE', 'OTHER NONCOLLISION', 
        'OVERTURNED', 'OTHER OBJECT', 'REAR TO SIDE', 'ANIMAL', 'TRAIN', 
        'REAR TO REAR'], n_samples),
    'trafficway_type': np.random.choice([
        'NOT DIVIDED', 'FOUR WAY', 'T-INTERSECTION', 'DIVIDED - W/MEDIAN (NOT RAISED)', 
        'OTHER', 'UNKNOWN INTERSECTION TYPE', 'ONE-WAY', 'RAMP', 'TRAFFIC ROUTE', 
        'FIVE POINT, OR MORE', 'DIVIDED - W/MEDIAN BARRIER', 'UNKNOWN', 'ALLEY', 
        'CENTER TURN LANE', 'L-INTERSECTION', 'DRIVEWAY', 'Y-INTERSECTION', 
        'PARKING LOT', 'ROUN'], n_samples),
    'alignment': np.random.choice([
        'STRAIGHT AND LEVEL', 'CURVE', 'LEVEL', 'STRAIGHT ON HILLCREST', 
        'STRAIGHT ON GRADE', 'CURVE ON GRADE', 'CURVE ON HILLCREST'], n_samples),
    'roadway_surface_cond': np.random.choice([
        'UNKNOWN', 'DRY', 'WET', 'SNOW OR SLUSH', 'ICE', 'OTHER', 
        'SAND', 'MUD', 'DIRT'], n_samples),
    'road_defect': np.random.choice([
        'UNKNOWN', 'NO DEFECTS', 'OTHER', 'SHOULDER DEFECT', 'WORN SURFACE', 
        'DEBRIS ON ROADWAY', 'RUT', 'HOLES'], n_samples),
    'crash_type': np.random.choice([
        'NO INJURY / DRIVE AWAY', 'INJURY AND / OR TOW DUE TO CRASH'], n_samples),
    'intersection_related_i': np.random.choice(['Y', 'N'], n_samples),
    'damage': np.random.choice([
        '$501 - $1,500', 'OVER $1,500', '$500 OR LESS'], n_samples),
    'prim_contributory_cause': np.random.choice([
        'UNABLE TO DETERMINE', 'IMPROPER TURNING/NO SIGNAL', 'FOLLOWING TOO CLOSELY', 
        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE', 'IMPROPER BACKING', 
        'FAILING TO YIELD RIGHT-OF-WAY', 'IMPROPER OVERTAKING/PASSING', 
        'DRIVING ON WRONG SIDE/WRONG WAY', 'IMPROPER LANE USAGE', 'NOT APPLICABLE', 
        'FAILING TO REDUCE SPEED TO AVOID CRASH', 'DISREGARDING TRAFFIC SIGNALS', 
        'WEATHER', 'DISREGARDING STOP SIGN', 'EQUIPMENT - VEHICLE CONDITION', 
        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER', 
        'DISREGARDING OTHER TRAFFIC SIGNS', 'TURNING RIGHT ON RED', 
        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)', 
        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST', 
        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)', 
        'DISTRACTION - FROM OUTSIDE VEHICLE', 'EXCEEDING SAFE SPEED FOR CONDITIONS', 
        'DISREGARDING ROAD MARKINGS', 'ROAD ENGINEERING/SURFACE/MARKING DEFECTS', 
        'PHYSICAL CONDITION OF DRIVER', 'DISTRACTION - FROM INSIDE VEHICLE', 
        'EXCEEDING AUTHORIZED SPEED LIMIT', 'ROAD CONSTRUCTION/MAINTENANCE', 
        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)', 
        'ANIMAL', 'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)', 
        'BICYCLE ADVANCING LEGALLY ON RED LIGHT', 'CELL PHONE USE OTHER THAN TEXTING', 
        'RELATED TO BUS STOP', 'TEXTING', 'OBSTRUCTED CROSSWALKS', 
        'DISREGARDING YIELD SIGN', 'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT', 
        'PASSING STOPPED SCHOOL BUS'], n_samples),
    'num_units': np.random.randint(1, 12, n_samples),
    'most_severe_injury': np.random.choice([
        'NO INDICATION OF INJURY', 'NONINCAPACITATING INJURY', 
        'INCAPACITATING INJURY', 'REPORTED, NOT EVIDENT', 'FATAL'], n_samples),
    'injuries_total': np.random.randint(0, 20, n_samples),
    'injuries_fatal': np.random.randint(0, 4, n_samples),
    'injuries_incapacitating': np.random.randint(0, 8, n_samples),
    'injuries_non_incapacitating': np.random.randint(0, 22, n_samples),
    'injuries_reported_not_evident': np.random.randint(0, 16, n_samples),
    'injuries_no_indication': np.random.randint(0, 50, n_samples),
    'crash_hour': np.random.randint(0, 24, n_samples),
    'crash_day_of_week': np.random.randint(1, 8, n_samples),
    'crash_month': np.random.randint(1, 13, n_samples),
})

# Lưu ra file CSV
df.to_csv('../data/simulated_crash_data.csv', index=False)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Đọc dataset từ file CSV
df = pd.read_csv(r"..\data\simulated_crash_data.csv", encoding='utf-8')  # Thử với utf-8 hoặc ISO-8859-1

import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Đọc dataset từ file CSV
df = pd.read_csv(r"..\data\simulated_crash_data.csv", encoding='utf-8')  # Thử với utf-8 hoặc ISO-8859-1

# Xóa cột "crash_date" nếu tồn tại
if "crash_date" in df.columns:
    df = df.drop(columns=["crash_date"])

if "damage" in df.columns:
    df = df.drop(columns=["damage"])

# Các cột cần mã hóa
categorical_columns = [
    "traffic_control_device", "weather_condition", "lighting_condition", "first_crash_type", 
    "trafficway_type", "alignment", "roadway_surface_cond", "road_defect", "crash_type", 
    "intersection_related_i", "prim_contributory_cause", "most_severe_injury"
]

# Dictionary để lưu các label encoder
decoders = {}

# Mã hóa từng cột
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])  # Thay đổi trực tiếp giá trị trong cột
    decoders[col] = dict(zip(le.classes_, le.transform(le.classes_)))  # Lưu mapping cho báo cáo

# Lưu dataset đã mã hóa
df.to_csv('../data/new_data_cleaned.csv', index=False)

# %%
import torch 
import pandas as pd 
import networkx as nx 
from itertools import combinations
from torch_geometric.data import Data 
from model import GAT

# %%
# Đọc dataset
file_path = r'..\data\new_data_cleaned.csv'
df = pd.read_csv(file_path)

# %%
import networkx as nx
from itertools import combinations

G = nx.Graph()
for index, row in df.iterrows():
    G.add_node(index, **row.to_dict())

def is_similar(accident1, accident2):
    return (
        abs(accident1['crash_hour'] - accident2['crash_hour']) <= 1 or
        accident1['crash_month'] == accident2['crash_month'] or
        accident1['crash_day_of_week'] == accident2['crash_day_of_week'] or
        accident1['trafficway_type'] == accident2['trafficway_type'] or
        accident1['first_crash_type'] == accident2['first_crash_type'] or
        accident1['injuries_no_indication'] == accident2['injuries_no_indication']
    )

for u, v in combinations(G.nodes(data=True), 2):
    if is_similar(u[1], v[1]):
        G.add_edge(u[0], v[0])

print(f"Đã tạo đồ thị với {G.number_of_nodes()} nút và {G.number_of_edges()} cạnh.")
# Out:
# Đã tạo đồ thị với 500 nút và 49038 cạnh.

# %%
import torch
from torch_geometric.data import Data

def networkx_to_pyg_inference(G):
    feature_attrs = list(next(iter(G.nodes(data=True)))[1].keys())

    features = [
        [float(data[attr]) for attr in feature_attrs]
        for _, data in G.nodes(data=True)
    ]

    x = torch.tensor(features, dtype=torch.float)

    node_mapping = {node: i for i, node in enumerate(G.nodes())}
    edge_index = torch.tensor(
        [[node_mapping[u], node_mapping[v]] for u, v in G.edges()],
        dtype=torch.long
    ).t().contiguous()

    return Data(x=x, edge_index=edge_index)

data_new = networkx_to_pyg_inference(G)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = GAT(in_features=22, hidden_dim=16, out_features=3, heads=8).to(device)
model.load_state_dict(torch.load('gat_model.pth', map_location=device))
model.eval()
# Out:
# GAT(
#   (gat1): GATConv(22, 16, heads=8)
#   (ln1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (gat2): GATConv(128, 16, heads=4)
#   (ln2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (gat3): GATConv(64, 3, heads=1)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
with torch.no_grad():
    out = model(data_new.x.to(device), data_new.edge_index.to(device))
    pred = out.argmax(dim=1)

df['predicted_damage'] = pred.cpu().numpy()

# %%
# Thêm giá trị predicted_damage vào đồ thị
for i, pred in enumerate(pred.cpu().numpy()):
    G.nodes[i]['predicted_damage'] = pred

# Kiểm tra lại giá trị đã được gán đúng chưa
for i in range(len(df)):
    print(f"Node {i} has predicted_damage = {G.nodes[i].get('predicted_damage')}")
# Out:
# Node 0 has predicted_damage = 0
# Node 1 has predicted_damage = 0
# Node 2 has predicted_damage = 0
# Node 3 has predicted_damage = 0
# Node 4 has predicted_damage = 0
# Node 5 has predicted_damage = 0
# Node 6 has predicted_damage = 1
# Node 7 has predicted_damage = 1
# Node 8 has predicted_damage = 0
# Node 9 has predicted_damage = 0
# Node 10 has predicted_damage = 1
# Node 11 has predicted_damage = 0
# Node 12 has predicted_damage = 1
# Node 13 has predicted_damage = 1
# Node 14 has predicted_damage = 0
# Node 15 has predicted_damage = 1
# Node 16 has predicted_damage = 1
# Node 17 has predicted_damage = 1
# Node 18 has predicted_damage = 0
# Node 19 has predicted_damage = 1
# Node 20 has predicted_damage = 1
# Node 21 has predicted_damage = 0
# Node 22 has predicted_damage = 1
# Node 23 has predicted_damage = 1
# Node 24 has predicted_damage = 1
# Node 25 has predicted_damage = 1
# Node 26 has predicted_damage = 1
# Node 27 has predicted_damage = 1
# Node 28 has predicted_damage = 1
# Node 29 has predicted_damage = 1
# Node 30 has predicted_damage = 1
# Node 31 has predicted_damage = 1
# Node 32 has predicted_damage = 1
# Node 33 has predicted_damage = 1
# Node 34 has predicted_damage = 1
# Node 35 has predicted_damage = 1
# Node 36 has predicted_damage = 1
# Node 37 has predicted_damage = 1
# Node 38 has predicted_damage = 1
# Node 39 has predicted_damage = 1
# Node 40 has predicted_damage = 1
# Node 41 has predicted_damage = 1
# Node 42 has predicted_damage = 1
# Node 43 has predicted_damage = 1
# Node 44 has predicted_damage = 1
# Node 45 has predicted_damage = 1
# Node 46 has predicted_damage = 1
# Node 47 has predicted_damage = 1
# Node 48 has predicted_damage = 1
# Node 49 has predicted_damage = 1
# Node 50 has predicted_damage = 1
# Node 51 has predicted_damage = 1
# Node 52 has predicted_damage = 1
# Node 53 has predicted_damage = 1
# Node 54 has predicted_damage = 1
# Node 55 has predicted_damage = 1
# Node 56 has predicted_damage = 1
# Node 57 has predicted_damage = 1
# Node 58 has predicted_damage = 1
# Node 59 has predicted_damage = 1
# Node 60 has predicted_damage = 1
# Node 61 has predicted_damage = 1
# Node 62 has predicted_damage = 1
# Node 63 has predicted_damage = 1
# Node 64 has predicted_damage = 1
# Node 65 has predicted_damage = 1
# Node 66 has predicted_damage = 1
# Node 67 has predicted_damage = 1
# Node 68 has predicted_damage = 1
# Node 69 has predicted_damage = 1
# Node 70 has predicted_damage = 1
# Node 71 has predicted_damage = 1
# Node 72 has predicted_damage = 1
# Node 73 has predicted_damage = 1
# Node 74 has predicted_damage = 1
# Node 75 has predicted_damage = 1
# Node 76 has predicted_damage = 1
# Node 77 has predicted_damage = 1
# Node 78 has predicted_damage = 1
# Node 79 has predicted_damage = 1
# Node 80 has predicted_damage = 1
# Node 81 has predicted_damage = 1
# Node 82 has predicted_damage = 1
# Node 83 has predicted_damage = 1
# Node 84 has predicted_damage = 1
# Node 85 has predicted_damage = 1
# Node 86 has predicted_damage = 1
# Node 87 has predicted_damage = 1
# Node 88 has predicted_damage = 1
# Node 89 has predicted_damage = 1
# Node 90 has predicted_damage = 1
# Node 91 has predicted_damage = 1
# Node 92 has predicted_damage = 1
# Node 93 has predicted_damage = 1
# Node 94 has predicted_damage = 1
# Node 95 has predicted_damage = 1
# Node 96 has predicted_damage = 1
# Node 97 has predicted_damage = 1
# Node 98 has predicted_damage = 1
# Node 99 has predicted_damage = 1
# Node 100 has predicted_damage = 1
# Node 101 has predicted_damage = 1
# Node 102 has predicted_damage = 1
# Node 103 has predicted_damage = 1
# Node 104 has predicted_damage = 1
# Node 105 has predicted_damage = 1
# Node 106 has predicted_damage = 1
# Node 107 has predicted_damage = 1
# Node 108 has predicted_damage = 1
# Node 109 has predicted_damage = 1
# Node 110 has predicted_damage = 1
# Node 111 has predicted_damage = 1
# Node 112 has predicted_damage = 1
# Node 113 has predicted_damage = 1
# Node 114 has predicted_damage = 1
# Node 115 has predicted_damage = 1
# Node 116 has predicted_damage = 1
# Node 117 has predicted_damage = 1
# Node 118 has predicted_damage = 1
# Node 119 has predicted_damage = 1
# Node 120 has predicted_damage = 1
# Node 121 has predicted_damage = 1
# Node 122 has predicted_damage = 1
# Node 123 has predicted_damage = 1
# Node 124 has predicted_damage = 1
# Node 125 has predicted_damage = 1
# Node 126 has predicted_damage = 1
# Node 127 has predicted_damage = 1
# Node 128 has predicted_damage = 1
# Node 129 has predicted_damage = 1
# Node 130 has predicted_damage = 1
# Node 131 has predicted_damage = 1
# Node 132 has predicted_damage = 1
# Node 133 has predicted_damage = 1
# Node 134 has predicted_damage = 1
# Node 135 has predicted_damage = 1
# Node 136 has predicted_damage = 1
# Node 137 has predicted_damage = 1
# Node 138 has predicted_damage = 1
# Node 139 has predicted_damage = 1
# Node 140 has predicted_damage = 1
# Node 141 has predicted_damage = 1
# Node 142 has predicted_damage = 1
# Node 143 has predicted_damage = 1
# Node 144 has predicted_damage = 1
# Node 145 has predicted_damage = 1
# Node 146 has predicted_damage = 1
# Node 147 has predicted_damage = 1
# Node 148 has predicted_damage = 1
# Node 149 has predicted_damage = 1
# Node 150 has predicted_damage = 1
# Node 151 has predicted_damage = 1
# Node 152 has predicted_damage = 1
# Node 153 has predicted_damage = 1
# Node 154 has predicted_damage = 1
# Node 155 has predicted_damage = 1
# Node 156 has predicted_damage = 1
# Node 157 has predicted_damage = 1
# Node 158 has predicted_damage = 1
# Node 159 has predicted_damage = 1
# Node 160 has predicted_damage = 1
# Node 161 has predicted_damage = 1
# Node 162 has predicted_damage = 1
# Node 163 has predicted_damage = 1
# Node 164 has predicted_damage = 1
# Node 165 has predicted_damage = 1
# Node 166 has predicted_damage = 1
# Node 167 has predicted_damage = 1
# Node 168 has predicted_damage = 1
# Node 169 has predicted_damage = 1
# Node 170 has predicted_damage = 1
# Node 171 has predicted_damage = 1
# Node 172 has predicted_damage = 1
# Node 173 has predicted_damage = 1
# Node 174 has predicted_damage = 1
# Node 175 has predicted_damage = 1
# Node 176 has predicted_damage = 1
# Node 177 has predicted_damage = 1
# Node 178 has predicted_damage = 1
# Node 179 has predicted_damage = 1
# Node 180 has predicted_damage = 1
# Node 181 has predicted_damage = 1
# Node 182 has predicted_damage = 1
# Node 183 has predicted_damage = 1
# Node 184 has predicted_damage = 1
# Node 185 has predicted_damage = 1
# Node 186 has predicted_damage = 1
# Node 187 has predicted_damage = 1
# Node 188 has predicted_damage = 1
# Node 189 has predicted_damage = 1
# Node 190 has predicted_damage = 1
# Node 191 has predicted_damage = 1
# Node 192 has predicted_damage = 1
# Node 193 has predicted_damage = 1
# Node 194 has predicted_damage = 1
# Node 195 has predicted_damage = 1
# Node 196 has predicted_damage = 1
# Node 197 has predicted_damage = 1
# Node 198 has predicted_damage = 1
# Node 199 has predicted_damage = 1
# Node 200 has predicted_damage = 1
# Node 201 has predicted_damage = 1
# Node 202 has predicted_damage = 1
# Node 203 has predicted_damage = 1
# Node 204 has predicted_damage = 1
# Node 205 has predicted_damage = 1
# Node 206 has predicted_damage = 1
# Node 207 has predicted_damage = 1
# Node 208 has predicted_damage = 1
# Node 209 has predicted_damage = 1
# Node 210 has predicted_damage = 1
# Node 211 has predicted_damage = 1
# Node 212 has predicted_damage = 1
# Node 213 has predicted_damage = 1
# Node 214 has predicted_damage = 1
# Node 215 has predicted_damage = 1
# Node 216 has predicted_damage = 1
# Node 217 has predicted_damage = 1
# Node 218 has predicted_damage = 1
# Node 219 has predicted_damage = 1
# Node 220 has predicted_damage = 1
# Node 221 has predicted_damage = 1
# Node 222 has predicted_damage = 1
# Node 223 has predicted_damage = 1
# Node 224 has predicted_damage = 1
# Node 225 has predicted_damage = 1
# Node 226 has predicted_damage = 1
# Node 227 has predicted_damage = 1
# Node 228 has predicted_damage = 1
# Node 229 has predicted_damage = 1
# Node 230 has predicted_damage = 1
# Node 231 has predicted_damage = 1
# Node 232 has predicted_damage = 1
# Node 233 has predicted_damage = 1
# Node 234 has predicted_damage = 1
# Node 235 has predicted_damage = 1
# Node 236 has predicted_damage = 1
# Node 237 has predicted_damage = 1
# Node 238 has predicted_damage = 1
# Node 239 has predicted_damage = 1
# Node 240 has predicted_damage = 1
# Node 241 has predicted_damage = 1
# Node 242 has predicted_damage = 1
# Node 243 has predicted_damage = 1
# Node 244 has predicted_damage = 1
# Node 245 has predicted_damage = 1
# Node 246 has predicted_damage = 1
# Node 247 has predicted_damage = 1
# Node 248 has predicted_damage = 1
# Node 249 has predicted_damage = 1
# Node 250 has predicted_damage = 1
# Node 251 has predicted_damage = 1
# Node 252 has predicted_damage = 1
# Node 253 has predicted_damage = 1
# Node 254 has predicted_damage = 1
# Node 255 has predicted_damage = 1
# Node 256 has predicted_damage = 1
# Node 257 has predicted_damage = 1
# Node 258 has predicted_damage = 1
# Node 259 has predicted_damage = 1
# Node 260 has predicted_damage = 1
# Node 261 has predicted_damage = 1
# Node 262 has predicted_damage = 1
# Node 263 has predicted_damage = 1
# Node 264 has predicted_damage = 1
# Node 265 has predicted_damage = 1
# Node 266 has predicted_damage = 1
# Node 267 has predicted_damage = 1
# Node 268 has predicted_damage = 1
# Node 269 has predicted_damage = 1
# Node 270 has predicted_damage = 1
# Node 271 has predicted_damage = 1
# Node 272 has predicted_damage = 1
# Node 273 has predicted_damage = 1
# Node 274 has predicted_damage = 1
# Node 275 has predicted_damage = 1
# Node 276 has predicted_damage = 1
# Node 277 has predicted_damage = 1
# Node 278 has predicted_damage = 1
# Node 279 has predicted_damage = 1
# Node 280 has predicted_damage = 1
# Node 281 has predicted_damage = 1
# Node 282 has predicted_damage = 1
# Node 283 has predicted_damage = 1
# Node 284 has predicted_damage = 1
# Node 285 has predicted_damage = 1
# Node 286 has predicted_damage = 1
# Node 287 has predicted_damage = 1
# Node 288 has predicted_damage = 1
# Node 289 has predicted_damage = 1
# Node 290 has predicted_damage = 1
# Node 291 has predicted_damage = 1
# Node 292 has predicted_damage = 1
# Node 293 has predicted_damage = 1
# Node 294 has predicted_damage = 1
# Node 295 has predicted_damage = 1
# Node 296 has predicted_damage = 1
# Node 297 has predicted_damage = 1
# Node 298 has predicted_damage = 1
# Node 299 has predicted_damage = 1
# Node 300 has predicted_damage = 1
# Node 301 has predicted_damage = 1
# Node 302 has predicted_damage = 1
# Node 303 has predicted_damage = 1
# Node 304 has predicted_damage = 1
# Node 305 has predicted_damage = 1
# Node 306 has predicted_damage = 1
# Node 307 has predicted_damage = 1
# Node 308 has predicted_damage = 1
# Node 309 has predicted_damage = 1
# Node 310 has predicted_damage = 1
# Node 311 has predicted_damage = 1
# Node 312 has predicted_damage = 1
# Node 313 has predicted_damage = 1
# Node 314 has predicted_damage = 1
# Node 315 has predicted_damage = 1
# Node 316 has predicted_damage = 1
# Node 317 has predicted_damage = 1
# Node 318 has predicted_damage = 1
# Node 319 has predicted_damage = 1
# Node 320 has predicted_damage = 1
# Node 321 has predicted_damage = 1
# Node 322 has predicted_damage = 1
# Node 323 has predicted_damage = 1
# Node 324 has predicted_damage = 1
# Node 325 has predicted_damage = 1
# Node 326 has predicted_damage = 1
# Node 327 has predicted_damage = 1
# Node 328 has predicted_damage = 1
# Node 329 has predicted_damage = 1
# Node 330 has predicted_damage = 1
# Node 331 has predicted_damage = 1
# Node 332 has predicted_damage = 1
# Node 333 has predicted_damage = 1
# Node 334 has predicted_damage = 1
# Node 335 has predicted_damage = 1
# Node 336 has predicted_damage = 1
# Node 337 has predicted_damage = 1
# Node 338 has predicted_damage = 1
# Node 339 has predicted_damage = 1
# Node 340 has predicted_damage = 1
# Node 341 has predicted_damage = 1
# Node 342 has predicted_damage = 1
# Node 343 has predicted_damage = 1
# Node 344 has predicted_damage = 1
# Node 345 has predicted_damage = 1
# Node 346 has predicted_damage = 1
# Node 347 has predicted_damage = 1
# Node 348 has predicted_damage = 1
# Node 349 has predicted_damage = 1
# Node 350 has predicted_damage = 1
# Node 351 has predicted_damage = 1
# Node 352 has predicted_damage = 1
# Node 353 has predicted_damage = 1
# Node 354 has predicted_damage = 1
# Node 355 has predicted_damage = 1
# Node 356 has predicted_damage = 1
# Node 357 has predicted_damage = 1
# Node 358 has predicted_damage = 1
# Node 359 has predicted_damage = 1
# Node 360 has predicted_damage = 1
# Node 361 has predicted_damage = 1
# Node 362 has predicted_damage = 1
# Node 363 has predicted_damage = 1
# Node 364 has predicted_damage = 1
# Node 365 has predicted_damage = 1
# Node 366 has predicted_damage = 1
# Node 367 has predicted_damage = 1
# Node 368 has predicted_damage = 1
# Node 369 has predicted_damage = 1
# Node 370 has predicted_damage = 1
# Node 371 has predicted_damage = 1
# Node 372 has predicted_damage = 1
# Node 373 has predicted_damage = 1
# Node 374 has predicted_damage = 1
# Node 375 has predicted_damage = 1
# Node 376 has predicted_damage = 1
# Node 377 has predicted_damage = 1
# Node 378 has predicted_damage = 1
# Node 379 has predicted_damage = 1
# Node 380 has predicted_damage = 1
# Node 381 has predicted_damage = 1
# Node 382 has predicted_damage = 1
# Node 383 has predicted_damage = 1
# Node 384 has predicted_damage = 1
# Node 385 has predicted_damage = 1
# Node 386 has predicted_damage = 1
# Node 387 has predicted_damage = 1
# Node 388 has predicted_damage = 1
# Node 389 has predicted_damage = 1
# Node 390 has predicted_damage = 1
# Node 391 has predicted_damage = 1
# Node 392 has predicted_damage = 1
# Node 393 has predicted_damage = 1
# Node 394 has predicted_damage = 1
# Node 395 has predicted_damage = 1
# Node 396 has predicted_damage = 1
# Node 397 has predicted_damage = 1
# Node 398 has predicted_damage = 1
# Node 399 has predicted_damage = 1
# Node 400 has predicted_damage = 1
# Node 401 has predicted_damage = 1
# Node 402 has predicted_damage = 1
# Node 403 has predicted_damage = 1
# Node 404 has predicted_damage = 1
# Node 405 has predicted_damage = 1
# Node 406 has predicted_damage = 1
# Node 407 has predicted_damage = 1
# Node 408 has predicted_damage = 1
# Node 409 has predicted_damage = 1
# Node 410 has predicted_damage = 1
# Node 411 has predicted_damage = 1
# Node 412 has predicted_damage = 1
# Node 413 has predicted_damage = 1
# Node 414 has predicted_damage = 1
# Node 415 has predicted_damage = 1
# Node 416 has predicted_damage = 1
# Node 417 has predicted_damage = 1
# Node 418 has predicted_damage = 1
# Node 419 has predicted_damage = 1
# Node 420 has predicted_damage = 1
# Node 421 has predicted_damage = 1
# Node 422 has predicted_damage = 1
# Node 423 has predicted_damage = 1
# Node 424 has predicted_damage = 1
# Node 425 has predicted_damage = 1
# Node 426 has predicted_damage = 1
# Node 427 has predicted_damage = 1
# Node 428 has predicted_damage = 1
# Node 429 has predicted_damage = 1
# Node 430 has predicted_damage = 1
# Node 431 has predicted_damage = 1
# Node 432 has predicted_damage = 1
# Node 433 has predicted_damage = 1
# Node 434 has predicted_damage = 1
# Node 435 has predicted_damage = 1
# Node 436 has predicted_damage = 1
# Node 437 has predicted_damage = 1
# Node 438 has predicted_damage = 1
# Node 439 has predicted_damage = 1
# Node 440 has predicted_damage = 1
# Node 441 has predicted_damage = 1
# Node 442 has predicted_damage = 1
# Node 443 has predicted_damage = 1
# Node 444 has predicted_damage = 1
# Node 445 has predicted_damage = 1
# Node 446 has predicted_damage = 1
# Node 447 has predicted_damage = 1
# Node 448 has predicted_damage = 1
# Node 449 has predicted_damage = 1
# Node 450 has predicted_damage = 1
# Node 451 has predicted_damage = 1
# Node 452 has predicted_damage = 1
# Node 453 has predicted_damage = 1
# Node 454 has predicted_damage = 1
# Node 455 has predicted_damage = 1
# Node 456 has predicted_damage = 1
# Node 457 has predicted_damage = 1
# Node 458 has predicted_damage = 1
# Node 459 has predicted_damage = 1
# Node 460 has predicted_damage = 1
# Node 461 has predicted_damage = 1
# Node 462 has predicted_damage = 1
# Node 463 has predicted_damage = 1
# Node 464 has predicted_damage = 1
# Node 465 has predicted_damage = 1
# Node 466 has predicted_damage = 1
# Node 467 has predicted_damage = 1
# Node 468 has predicted_damage = 1
# Node 469 has predicted_damage = 1
# Node 470 has predicted_damage = 1
# Node 471 has predicted_damage = 1
# Node 472 has predicted_damage = 1
# Node 473 has predicted_damage = 1
# Node 474 has predicted_damage = 1
# Node 475 has predicted_damage = 1
# Node 476 has predicted_damage = 1
# Node 477 has predicted_damage = 1
# Node 478 has predicted_damage = 1
# Node 479 has predicted_damage = 1
# Node 480 has predicted_damage = 1
# Node 481 has predicted_damage = 1
# Node 482 has predicted_damage = 1
# Node 483 has predicted_damage = 1
# Node 484 has predicted_damage = 1
# Node 485 has predicted_damage = 1
# Node 486 has predicted_damage = 1
# Node 487 has predicted_damage = 1
# Node 488 has predicted_damage = 1
# Node 489 has predicted_damage = 1
# Node 490 has predicted_damage = 1
# Node 491 has predicted_damage = 1
# Node 492 has predicted_damage = 1
# Node 493 has predicted_damage = 1
# Node 494 has predicted_damage = 1
# Node 495 has predicted_damage = 1
# Node 496 has predicted_damage = 1
# Node 497 has predicted_damage = 1
# Node 498 has predicted_damage = 1
# Node 499 has predicted_damage = 1

# %%
# Mapping số về chuỗi như trong cột damage gốc
damage_mapping = {
    0: "$500 OR LESS",
    1: "$501 - $1,500",
    2: "OVER $1,500"
}

# Tạo cột mới với nhãn dạng chuỗi
df['predicted_damage_label'] = df['predicted_damage'].map(damage_mapping)

print(df[['predicted_damage', 'predicted_damage_label']])
# Out:
#      predicted_damage predicted_damage_label
# 0                   0           $500 OR LESS
# 1                   0           $500 OR LESS
# 2                   0           $500 OR LESS
# 3                   0           $500 OR LESS
# 4                   0           $500 OR LESS
# ..                ...                    ...
# 495                 1          $501 - $1,500
# 496                 1          $501 - $1,500
# 497                 1          $501 - $1,500
# 498                 1          $501 - $1,500
# 499                 1          $501 - $1,500
#
# [500 rows x 2 columns]

# %%
from collections import Counter, defaultdict

def analyze_high_damage_nodes(G, label_attr='predicted_damage', high_level=1, top_k=3):
    # Bước 1: Lọc các node có predicted_damage bằng high_level
    high_damage_nodes = [n for n, data in G.nodes(data=True) if data.get(label_attr) == high_level]

    # Kiểm tra nếu không có node nào
    if not high_damage_nodes:
        print(f"No nodes found with {label_attr} = {high_level}")
        return

    # Bước 2: Thống kê các feature xuất hiện trong nhóm này
    feature_counters = defaultdict(Counter)

    for n in high_damage_nodes:
        node_data = G.nodes[n]
        for attr, value in node_data.items():
            if attr != label_attr:
                feature_counters[attr][value] += 1

    # Bước 3: In ra top K giá trị phổ biến nhất cho từng feature
    print(f"\nTop nguyên nhân thường thấy khi `{label_attr} = {high_level}`:\n")
    for attr, counter in feature_counters.items():
        print(f"- {attr}:")
        for val, freq in counter.most_common(top_k):
            print(f"   • {val}: {freq} lần")
        print()

# %%
analyze_high_damage_nodes(G, label_attr='predicted_damage', high_level=0)
# Out:
# Top nguyên nhân thường thấy khi `predicted_damage = 0`:
#
# - traffic_control_device:
#    • 12: 2 lần
#    • 3: 2 lần
#    • 17: 1 lần
#
# - weather_condition:
#    • 13: 3 lần
#    • 11: 3 lần
#    • 8: 2 lần
#
# - lighting_condition:
#    • 4: 6 lần
#    • 1: 3 lần
#    • 5: 2 lần
#
# - first_crash_type:
#    • 17: 2 lần
#    • 6: 2 lần
#    • 13: 2 lần
#
# - trafficway_type:
#    • 12: 2 lần
#    • 4: 2 lần
#    • 17: 1 lần
#
# - alignment:
#    • 4: 4 lần
#    • 5: 3 lần
#    • 1: 3 lần
#
# - roadway_surface_cond:
#    • 1: 3 lần
#    • 7: 3 lần
#    • 5: 2 lần
#
# - road_defect:
#    • 5: 4 lần
#    • 0: 2 lần
#    • 3: 2 lần
#
# - crash_type:
#    • 1: 8 lần
#    • 0: 4 lần
#
# - intersection_related_i:
#    • 0: 6 lần
#    • 1: 6 lần
#
# - prim_contributory_cause:
#    • 14: 1 lần
#    • 19: 1 lần
#    • 13: 1 lần
#
# - num_units:
#    • 4: 3 lần
#    • 2: 3 lần
#    • 5: 2 lần
#
# - most_severe_injury:
#    • 4: 3 lần
#    • 0: 3 lần
#    • 2: 3 lần
#
# - injuries_total:
#    • 18: 2 lần
#    • 12: 2 lần
#    • 0: 1 lần
#
# - injuries_fatal:
#    • 3: 5 lần
#    • 2: 3 lần
#    • 1: 2 lần
#
# - injuries_incapacitating:
#    • 5: 4 lần
#    • 3: 3 lần
#    • 4: 2 lần
#
# - injuries_non_incapacitating:
#    • 20: 3 lần
#    • 5: 2 lần
#    • 3: 2 lần
#
# - injuries_reported_not_evident:
#    • 2: 2 lần
#    • 12: 2 lần
#    • 6: 1 lần
#
# - injuries_no_indication:
#    • 17: 2 lần
#    • 12: 1 lần
#    • 4: 1 lần
#
# - crash_hour:
#    • 6: 2 lần
#    • 10: 1 lần
#    • 21: 1 lần
#
# - crash_day_of_week:
#    • 2: 4 lần
#    • 7: 3 lần
#    • 4: 2 lần
#
# - crash_month:
#    • 3: 2 lần
#    • 2: 2 lần
#    • 6: 2 lần

# %%
analyze_high_damage_nodes(G, label_attr='predicted_damage', high_level=1)
# Out:
# Top nguyên nhân thường thấy khi `predicted_damage = 1`:
#
# - traffic_control_device:
#    • 7: 36 lần
#    • 12: 35 lần
#    • 16: 35 lần
#
# - weather_condition:
#    • 13: 49 lần
#    • 2: 44 lần
#    • 1: 41 lần
#
# - lighting_condition:
#    • 1: 94 lần
#    • 4: 84 lần
#    • 5: 84 lần
#
# - first_crash_type:
#    • 14: 36 lần
#    • 3: 32 lần
#    • 15: 32 lần
#
# - trafficway_type:
#    • 13: 39 lần
#    • 8: 33 lần
#    • 11: 31 lần
#
# - alignment:
#    • 6: 87 lần
#    • 1: 81 lần
#    • 4: 68 lần
#
# - roadway_surface_cond:
#    • 7: 69 lần
#    • 4: 63 lần
#    • 3: 61 lần
#
# - road_defect:
#    • 5: 68 lần
#    • 1: 64 lần
#    • 6: 63 lần
#
# - crash_type:
#    • 0: 258 lần
#    • 1: 230 lần
#
# - intersection_related_i:
#    • 1: 251 lần
#    • 0: 237 lần
#
# - prim_contributory_cause:
#    • 8: 20 lần
#    • 24: 20 lần
#    • 3: 19 lần
#
# - num_units:
#    • 2: 62 lần
#    • 6: 52 lần
#    • 1: 52 lần
#
# - most_severe_injury:
#    • 3: 110 lần
#    • 0: 108 lần
#    • 4: 96 lần
#
# - injuries_total:
#    • 16: 33 lần
#    • 11: 31 lần
#    • 12: 30 lần
#
# - injuries_fatal:
#    • 0: 134 lần
#    • 1: 126 lần
#    • 3: 119 lần
#
# - injuries_incapacitating:
#    • 4: 80 lần
#    • 6: 66 lần
#    • 3: 64 lần
#
# - injuries_non_incapacitating:
#    • 1: 30 lần
#    • 13: 27 lần
#    • 17: 27 lần
#
# - injuries_reported_not_evident:
#    • 13: 38 lần
#    • 5: 36 lần
#    • 7: 36 lần
#
# - injuries_no_indication:
#    • 7: 15 lần
#    • 34: 15 lần
#    • 32: 13 lần
#
# - crash_hour:
#    • 23: 30 lần
#    • 5: 27 lần
#    • 8: 27 lần
#
# - crash_day_of_week:
#    • 6: 76 lần
#    • 4: 74 lần
#    • 7: 71 lần
#
# - crash_month:
#    • 10: 50 lần
#    • 11: 46 lần
#    • 2: 45 lần
